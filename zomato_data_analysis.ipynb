# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh2228/Data_Analysis/blob/main/zomato_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Zomato data .csv')
print(df)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# 2                            800          Buffet
# 3                            300          Buffet
# 4                            600          Buffet
# ..                           ...             ...
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining
#
# [148 rows x 7 columns]

# %%
# converting rating coloumn in appropriate form :removing /5
def handle_rating(value):
  value=str(value).split('/')
  value=value[0]
  return float(value)

df['rate']=df['rate'].apply(handle_rating)
print(df['rate'])
# Out:
# 0      4.1
# 1      4.1
# 2      3.8
# 3      3.7
# 4      3.8
#       ...
# 143    3.3
# 144    3.3
# 145    4.0
# 146    3.0
# 147    3.9
# Name: rate, Length: 148, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# # Majority Type of Resturants

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['rate'].plot(kind='hist', bins=20, title='rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['votes'].plot(kind='hist', bins=20, title='votes')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['approx_cost(for two people)'].plot(kind='hist', bins=20, title='approx_cost(for two people)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('online_order').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('book_table').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='rate', y='votes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='votes', y='approx_cost(for two people)', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['rate'].plot(kind='line', figsize=(8, 4), title='rate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['votes'].plot(kind='line', figsize=(8, 4), title='votes')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['approx_cost(for two people)'].plot(kind='line', figsize=(8, 4), title='approx_cost(for two people)')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['online_order'].value_counts()
#     for x_label, grp in _df_11.groupby('name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('name')
# _ = plt.ylabel('online_order')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['book_table'].value_counts()
#     for x_label, grp in _df_12.groupby('online_order')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('online_order')
# _ = plt.ylabel('book_table')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='rate', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['online_order'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='rate', y='online_order', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['book_table'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='rate', y='book_table', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='votes', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
sns.countplot(x=df['listed_in(type)'])
plt.xlabel('type of resturant')
plt.ylabel('count')
plt.title('Majority type of resturant')
# Out:
# Text(0.5, 1.0, 'Majority type of resturant')

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df=pd.read_csv('Zomato data .csv')


grouped_data=df.groupby('listed_in(type)')['votes'].sum()
result=pd.DataFrame({'votes': grouped_data})
plt.plot(result,c="orange",marker="o")
plt.xlabel("Types of resturant",c="red",size=15)
plt.ylabel("Votes",c="green",size=15)
plt.title('Type of Resturant with Maximum Voting',c="blue")
# Out:
# Text(0.5, 1.0, 'Type of Resturant with Maximum Voting')

# %%
df['rate']=df['rate'].apply(handle_rating)
plt.hist(df['rate'],bins=50)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Distribution of Ratings')
plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x='rate', y='votes',
                 hover_data=['name', 'listed_in(type)'],  # Add hover data
                 title='Relationship between Ratings and Votes')
fig.show()

# Interactive Visualization 2: Box plot with selectable restaurant types
restaurant_types = df['listed_in(type)'].unique()  # Get all unique restaurant types
fig = px.box(df, x='listed_in(type)', y='approx_cost(for two people)',
             color='listed_in(type)',  # Add color for distinction
             title='Cost Comparison by Restaurant Type')
# Add dropdown menu for selecting restaurant types
fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(
                    args=[{'x': [df['listed_in(type)'][df['listed_in(type)'] == type]]}],  # Filter data
                    label=type,
                    method='restyle'
                ) for type in restaurant_types
            ],
            direction='down',
            pad={'r': 10, 't': 10},
            showactive=True,
            x=0.1,
            xanchor='left',
            y=1.1,
            yanchor='top'
        ),
    ]
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c1b10ee-a15c-4e24-9e64-691453008ab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c1b10ee-a15c-4e24-9e64-691453008ab3")) {                    Plotly.newPlot(                        "3c1b10ee-a15c-4e24-9e64-691453008ab3",                        [{"customdata":[["Jalsa","Buffet"],["Spice Elephant","Buffet"],["San Churro Cafe","Buffet"],["Addhuri Udupi Bhojana","Buffet"],["Grand Village","Buffet"],["Timepass Dinner","Buffet"],["Rosewood International Hotel - Bar & Restaurant","Buffet"],["Onesta","Cafes"],["Penthouse Cafe","other"],["Smacznego","Cafes"],["Village Café","Cafes"],["Cafe Shuffle","Cafes"],["The Coffee Shack","Cafes"],["Caf-Eleven","Cafes"],["San Churro Cafe","Cafes"],["Cafe Vivacity","Cafes"],["Catch-up-ino","Cafes"],["Kirthi's Biryani","Cafes"],["T3H Cafe","Cafes"],["360 Atoms Restaurant And Cafe","Cafes"],["The Vintage Cafe","Cafes"],["Woodee Pizza","Cafes"],["Cafe Coffee Day","Cafes"],["My Tea House","Cafes"],["Hide Out Cafe","Cafes"],["CAFE NOVA","Cafes"],["Coffee Tindi","Cafes"],["Sea Green Cafe","Cafes"],["Cuppa","Cafes"],["Srinathji's Cafe","Cafes"],["Redberrys","Cafes"],["Foodiction","other"],["Sweet Truth","Dining"],["Ovenstory Pizza","Dining"],["Faasos","other"],["Behrouz Biryani","Dining"],["Fast And Fresh","Dining"],["Szechuan Dragon","Dining"],["Empire Restaurant","other"],["Maruthi Davangere Benne Dosa","Dining"],["Chaatimes","Dining"],["Havyaka Mess","Dining"],["McDonald's","Dining"],["Domino's Pizza","Dining"],["Onesta","other"],["Hotboxit","Dining"],["Kitchen Garden","Dining"],["Recipe","Dining"],["Beijing Bites","Dining"],["Tasty Bytes","Dining"],["Petoo","Dining"],["Shree Cool Point","Dining"],["Corner House Ice Cream","Dining"],["Biryanis And More","Dining"],["Roving Feast","Dining"],["FreshMenu","Dining"],["Banashankari Donne Biriyani","Dining"],["Wamama","other"],["Five Star Chicken","Dining"],["XO Belgian Waffle","Dining"],["Peppy Peppers","other"],["Goa 0 Km","Dining"],["Chinese Kitchen","Dining"],["Jeet Restaurant","Dining"],["Cake of the Day","Dining"],["Kabab Magic","Dining"],["Namma Brahmin's Idli","Dining"],["Gustoes Beer House","Dining"],["Sugar Rush","Dining"],["Burger King","Dining"],["The Good Bowl","Dining"],["The Biryani Cafe","Dining"],["Spicy Tandoor","Dining"],["LSD Cafe","other"],["Rolls On Wheels","Dining"],["Om Sri Vinayaka Chats","Dining"],["Sri Guru Kottureshwara Davangere Benne Dosa","Dining"],["Devanna Dum Biriyani Centre","Dining"],["Kolbeh","Dining"],["Upahar Sagar","Dining"],["Kadalu Sea Food Restaurant","Dining"],["Frozen Bottle","Dining"],["Parimala Sweets","Dining"],["Vaishali Deluxe","Dining"],["Chill Out","Dining"],["The Big O Bakes","Dining"],["Meghana Foods","Dining"],["Krishna Sagar","Dining"],["Dessert Rose","Dining"],["Chickpet Donne Biryani House","Dining"],["Me And My Cake","Dining"],["Sunsadm","Dining"],["Annapooraneshwari Mess","Dining"],["Thanco's Natural Ice Creams","Dining"],["Nandhini Deluxe","Dining"],["Vi Ra's Bar and Restaurant","Dining"],["Kaggis","Dining"],["Ayda Persian Kitchen","Dining"],["Chatar Patar","Dining"],["Polar Bear","Dining"],["Kidambi's Kitchen","Dining"],["Mane Thindi","Dining"],["Kotian Karavali Restaurant","Dining"],["Floured-Baked With Love","Dining"],["CAFE NOVA","Dining"],["Cakes & Slices","Dining"],["Spice 9","Dining"],["Coffee Shopee","Dining"],["Naveen Kabab & Biriyani Mane","Dining"],["Katriguppe Donne Biryani","Dining"],["Hari Super Sandwich","Dining"],["Atithi Point Ande Ka Funda","Dining"],["Just Bake","Dining"],["Dharwad Line Bazaar Mishra Pedha","Dining"],["Cake Bite","Dining"],["Aarush's Food Plaza","Dining"],["Wood Stove","Dining"],["Kulfi & More","Dining"],["Kannadigas Karavali","Dining"],["K27 - The Pu ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8aea2995-ddf0-49ec-bb56-652b6e613b46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8aea2995-ddf0-49ec-bb56-652b6e613b46")) {                    Plotly.newPlot(                        "8aea2995-ddf0-49ec-bb56-652b6e613b46",                        [{"alignmentgroup":"True","hovertemplate":"listed_in(type)=%{x}\u003cbr\u003eapprox_cost(for two people)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Buffet","marker":{"color":"#636efa"},"name":"Buffet","notched":false,"offsetgroup":"Buffet","orientation":"v","showlegend":true,"x":["Buffet","Buffet","Buffet","Buffet","Buffet","Buffet","Buffet"],"x0":" ","xaxis":"x","y":[800,800,800,300,600,600,800],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"listed_in(type)=%{x}\u003cbr\u003eapprox_cost(for two people)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cafes","marker":{"color":"#EF553B"},"name":"Cafes","notched":false,"offsetgroup":"Cafes","orientation":"v","showlegend":true,"x":["Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes","Cafes"],"x0":" ","xaxis":"x","y":[600,550,500,600,500,450,800,650,800,700,300,400,400,500,900,600,300,600,200,500,550,550,600],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"listed_in(type)=%{x}\u003cbr\u003eapprox_cost(for two people)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"other","marker":{"color":"#00cc96"},"name":"other","notched":false,"offsetgroup":"other","orientation":"v","showlegend":true,"x":["other","other","other","other","other","other","other","other"],"x0":" ","xaxis":"x","y":[700,500,500,750,600,800,800,700],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"listed_in(type)=%{x}\u003cbr\u003eapprox_cost(for two people)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dining","marker":{"color":"#ab63fa"},"name":"Dining","notched":false,"offsetgroup":"Dining","orientation":"v","showlegend":true,"x":["Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining","Dining"],"x0":" ","xaxis":"x","y":[500,750,650,400,600,150,200,300,500,800,400,300,450,850,300,450,150,400,750,450,450,300,200,400,800,150,850,150,400,100,700,300,600,500,300,150,300,500,150,300,500,350,500,400,200,700,100,300,600,200,500,250,500,400,200,300,600,800,250,950,300,400,300,200,300,400,600,300,300,250,300,300,200,150,400,150,300,200,150,150,250,900,300,200,100,200,200,400,350,100,150,150,200,100,400,200,150,400,150,250,250,150,200,350,300,100,150,450,800,200],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorba ...

# %%
couple_data = df['approx_cost(for two people)']
sns.countplot(x=couple_data, palette='viridis')
plt.xlabel('Approximate Cost for Two People', fontsize=12, color='red')
plt.ylabel('Number of Restaurants', fontsize=12, color='green')
plt.title('Distribution of Restaurant Costs', fontsize=14, color='purple')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-45-72f28c88b95f>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
